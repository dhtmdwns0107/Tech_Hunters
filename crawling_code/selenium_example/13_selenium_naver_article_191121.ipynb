# %%
import requests
import time
import pandas as pd
from selenium import webdriver
from PIL import Image as pil
from bs4 import BeautifulSoup

# %%
categories = {
100: "정치",
101: "경제",
102: "사회",
103: "생활/문화",
104: "세계",
105: "IT/과학"
}

# %%
category, date, page = 100, 20191121 ,1

url = 'https://news.naver.com/main/list.nhn?mode=LSD&mid=sec&sid1={}&page={}'.format(category, date, page)

# %%
driver = webdriver.Chrome()
driver.get(url)

# %%
articles = driver.find_elements_by_css_selector(".list_body > ul> li")

# %%
title = articles[0].find_element_by_css_selector("dt:not(.photo) > a").text
link = articles[0].find_element_by_css_selector("dt:not(.photo) > a")\
.get_attribute("href")
title, link
# Out:
# ('[사진] 황교안 단식 농성',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=025&aid=0002954433')

# %%
response =requests.get(link)
dom = BeautifulSoup(response.content, "html.parser")

# %%
content = dom.select_one("#articleBodyContents").text\
.replace("\n","").replace("\'","").split("{}")[1].strip()
content
# Out:
# '황교안 단식 농성           황교안 자유한국당 대표가 20일 한일군사정보보호협정(GSOMIA·지소미아) 파기 철회, 고위공직자범죄수사처(공수처) 법 포기, 연동형 비례대표제의 선거법 철회를 요구하며 무기한 단식 농성에 들어갔다. 황 대표는 청와대 관계규정 및 경호상 문제 등을 이유로 당초 계획했던 청와대 분수대 앞 단식 계획을 수정하고 이날 밤부터 국회로 자리를 옮겨 단식을 이어갔다.      우상조 기자  ▶ 미세먼지 심한 날엔? 먼지알지!▶ 중앙일보 홈페이지 / 페이스북 친구추가ⓒ중앙일보(https://joongang.co.kr), 무단 전재 및 재배포 금지'

# %%
def get_articles(category, date, page):
    url = 'https://news.naver.com/main/list.nhn?mode=LSD&mid=sec&sid1={}&page={}'.format(category, date, page)
    driver = webdriver.Chrome()
    driver.get(url)
    articles = driver.find_elements_by_css_selector(".list_body > ul> li")
    datas = []
    for article in articles:
        title = article.find_element_by_css_selector("dt:not(.photo) > a").text
        link = article.find_element_by_css_selector("dt:not(.photo) >a").get_attribute("href")
        response =requests.get(link)
        dom = BeautifulSoup(response.content, "html.parser")
        content = dom.select_one("#articleBodyContents").text.replace("\n","").replace("\'","").split("{}")[1].strip()
        datas.append({
            "title" : title,
            "link" : link,
            "content" : content,
            "category" : category,
        })
    driver.quit()
        
    return pd.DataFrame(datas)

# %%
get_articles(100,20191121 ,1)
# Out:
#     category                                            content  \
# 0        100  2019년 한겨레-부산 국제심포지엄강연 | 스미스 영국대사사이먼 스미스 주한 영국대...
# 1        100  자유한국당이 이르면 오늘 현역 물갈이 폭을 담은 내년 총선 공천 기준안을 확정해 발...
# 2        100  2019 한겨레-부산 국제심포지엄 토론 | 문정인 이종석 정세현 ‘한반도 평화’ 정...
# 3        100  지소미아 종료시한 전후로 방일…유지 압박한 美역할 관심지소미아 종료 시한 째깍…美압...
# 4        100  더불어민주당 이인영(가운데), 자유한국당 나경원(왼쪽), 바른미래당 오신환 원내대표...
# 5        100  황교안 단식 농성           황교안 자유한국당 대표가 20일 한일군사정보보호...
# 6        100  15일 “현 수준 유지” 서명 번복김현종 18일 방미 지소미아 논의  마크 에스퍼 ...
# 7        100  83년 YS의 단식투쟁      90년 DJ의 단식투쟁           1983년...
# 8        100  베트남 간 에스퍼 미 국방           마크 에스퍼 미 국방장관(왼쪽)이 20...
# 9        100  질문자 무작위 선정했다지만19명 중 5명이 대통령과 구면박지원 “탁현민 빈자리 크구...
# 10       100  국민과 대화 때 지소미아 관련 발언“한국이 안보 방파제 역할해줘일본은 GDP 1%만...
# 11       100  日 "(한국 측에) 현명한 대응 확실히 요구해갈 것"    연합뉴스     김현종 ...
# 12       100  문희상 국회의장. 연합뉴스.문희상 국회의장이 일제 강제징용 피해자 배상 문제 해법으...
#
#                                                  link  \
# 0   https://news.naver.com/main/read.nhn?mode=LSD&...
# 1   https://news.naver.com/main/read.nhn?mode=LSD&...
# 2   https://news.naver.com/main/read.nhn?mode=LSD&...
# 3   https://news.naver.com/main/read.nhn?mode=LSD&...
# 4   https://news.naver.com/main/read.nhn?mode=LSD&...
# 5   https://news.naver.com/main/read.nhn?mode=LSD&...
# 6   https://news.naver.com/main/read.nhn?mode=LSD&...
# 7   https://news.naver.com/main/read.nhn?mode=LSD&...
# 8   https://news.naver.com/main/read.nhn?mode=LSD&...
# 9   https://news.naver.com/main/read.nhn?mode=LSD&...
# 10  https://news.naver.com/main/read.nhn?mode=LSD&...
# 11  https://news.naver.com/main/read.nhn?mode=LSD&...
# 12  https://news.naver.com/main/read.nhn?mode=LSD&...
#
#                                             title
# 0                  “문재인 정부, 북 개방화하려는 노력 발전시켜 나가야”
# 1              한국당, 이르면 오늘 공천 기준안 발표...현역 물갈이폭 포함
# 2            “경제 부흥 원하는 김정은, 제재 완화 없이는 핵 협상 안할 것”
# 3         美국무부 설리번·스틸웰, 日 G20 참석…지소미아 막판협의 주목(종합)
# 4            홍준표 "황교안 목숨 건 단식 첫날, 나경원 워싱턴행 이해 안돼"
# 5                                  [사진] 황교안 단식 농성
# 6                       에스퍼 “주한미군 감축 할지말지 예측 않겠다”
# 7                       [사진] 83년 YS, 90년 DJ의 단식투쟁
# 8                             [사진] 베트남 간 에스퍼 미 국방
# 9   [현장에서] 대통령 감성 돋보인 ‘좋은 쇼’ 국민 궁금한 건 못들은 ‘나쁜 소통’
# 10              문 대통령 ‘일본 안보 방파제론’…트럼프 무임승차론 닮은꼴?
# 11           靑 김현종, 지소미아 종료 앞두고 극비 방미…우리 정부 입장 설명
# 12      문희상 국회의장, ‘강제징용 피해자 배상 문제’ 해법 담은 법안 발의 예정

# %%
dfs = []
date = 20191121
for category in categories:
    print(categories[category], end=" ")
    for page in range(1,6):
        print(page, end=" ")
        df = get_articles(category, date, page)
        dfs.append(df)
    print()
articles_df = pd.concat(dfs, ignore_index=True)
articles_df.tail()
# Out:
# 정치 1 2 3 4 5
# 경제 1 2 3 4 5
# 사회 1 2 3 4 5
# 생활/문화 1 2 3 4 5
# 세계 1 2 3 4 5
# IT/과학 1 2 3 4 5
#      category                                            content  \
# 206       105  20일 열린 기자간담회에서 김훈 개발실장이 퍼플에 대해서 설명하고 있다. /최승진 ...
# 207       105  지난해 11월 24일 KT 아현국사 화재 이후 방송통신위원회가 그간 추진해온 화재 ...
# 208       105  김형정 XN시스템즈 대표“내년에 올해보다 더 좋은 경영성과를 거두는 것은 물론 신기...
# 209       105  갤럭시폴드를 앞세운 삼성전자가 오는 22일 화웨이와 폴더블폰 정면 대결을 벌인다. ...
# 210       105  20일 열린 기자간담회에서 김훈 개발실장이 퍼플에 대해서 설명하고 있다. /최승진 ...
#
#                                                   link  \
# 206  https://news.naver.com/main/read.nhn?mode=LSD&...
# 207  https://news.naver.com/main/read.nhn?mode=LSD&...
# 208  https://news.naver.com/main/read.nhn?mode=LSD&...
# 209  https://news.naver.com/main/read.nhn?mode=LSD&...
# 210  https://news.naver.com/main/read.nhn?mode=LSD&...
#
#                                        title
# 206             리니지2M이 퍼플과 만나니…'PC게임 부럽지 않네'
# 207  KT 아현 화재 1년...방통위, 손해배상 확대·위약금 면제 기준 완화
# 208    XN시스템즈, 새로운 무선보안 기술 개발... 미래 먹거리 준비한다
# 209         [TF초점] '갤럭시폴드' 中 6차 판매 관심 쏠리는 이유
# 210             리니지2M이 퍼플과 만나니…'PC게임 부럽지 않네'

# %%
articles_df.to_csv("article.csv", index=False, encoding="utf-8-sig")

# %%
articles_df.tail()
# Out:
#      category                                            content  \
# 206       105  20일 열린 기자간담회에서 김훈 개발실장이 퍼플에 대해서 설명하고 있다. /최승진 ...
# 207       105  지난해 11월 24일 KT 아현국사 화재 이후 방송통신위원회가 그간 추진해온 화재 ...
# 208       105  김형정 XN시스템즈 대표“내년에 올해보다 더 좋은 경영성과를 거두는 것은 물론 신기...
# 209       105  갤럭시폴드를 앞세운 삼성전자가 오는 22일 화웨이와 폴더블폰 정면 대결을 벌인다. ...
# 210       105  20일 열린 기자간담회에서 김훈 개발실장이 퍼플에 대해서 설명하고 있다. /최승진 ...
#
#                                                   link  \
# 206  https://news.naver.com/main/read.nhn?mode=LSD&...
# 207  https://news.naver.com/main/read.nhn?mode=LSD&...
# 208  https://news.naver.com/main/read.nhn?mode=LSD&...
# 209  https://news.naver.com/main/read.nhn?mode=LSD&...
# 210  https://news.naver.com/main/read.nhn?mode=LSD&...
#
#                                        title
# 206             리니지2M이 퍼플과 만나니…'PC게임 부럽지 않네'
# 207  KT 아현 화재 1년...방통위, 손해배상 확대·위약금 면제 기준 완화
# 208    XN시스템즈, 새로운 무선보안 기술 개발... 미래 먹거리 준비한다
# 209         [TF초점] '갤럭시폴드' 中 6차 판매 관심 쏠리는 이유
# 210             리니지2M이 퍼플과 만나니…'PC게임 부럽지 않네'
