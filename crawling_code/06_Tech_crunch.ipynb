# %%
from selenium import webdriver

# %%
#!pip install selenium

# %%
url = 'http://www.itworld.co.kr/search/?q=AI'  #.format(page)

# %%
#from selenium.webdriver.common.keys import Keys
import time

driver =  webdriver.Chrome()
driver.get(url)

driver.implicitly_wait(5)

div = driver.find_elements_by_css_selector('.gsc-wrapper')[0]
btn = div.find_elements_by_css_selector('.gsc-cursor-page')[2]

btn.click()

#driver.find_element_by_xpath("""//*[@id="___gcse_0"]/div/div/div/div[5]/div[2]/div[1]/div/div[2]/div/div[5]""").click()

# %%
#여러데이터 모으기
articles = driver.find_elements_by_css_selector("#___gcse_0 > div > div > div > div.gsc-wrapper > div.gsc-resultsbox-visible > div.gsc-resultsRoot.gsc-tabData.gsc-tabdActive > div > div.gsc-expansionArea > div > div.gs-webResult.gs-result")
                                                

len(articles)
# Out:
# 10

# %%
#제목 뽑기  > 

import pandas as pd

title_list = []
for article in articles:
    title = article.find_element_by_css_selector("div.gsc-thumbnail-inside > div > a").text 
    title_list.append(title)
title =pd.DataFrame(title_list, columns=['title'])
title.head()
# Out:
#                                                title
# 0  “2022년까지 AI 프로젝트 85%가 잘못된 결과 도출"…가트너 - ITWorld...
# 1  IDG 블로그 | SaaS 기반 AI 학습 서비스의 엄청난 가능성 - ITWorld...
# 2     마그넷 포렌식, AI 기능 더한 디지털 포렌식 솔루션 '마그넷 엑시엄 1.1 ...
# 3      “CPU도 AI 시대” 인텔 10세대 아이스레이크 코어 프로세서 성능 해부 ...
# 4         향후 10년 AI 투명성의 위험을 완화하는 방법 - ITWorld Korea

# %%
# 링크 뽑기
#___gcse_1 > div > div > div > div.gsc-wrapper > div.gsc-resultsbox-visible > div.gsc-resultsRoot.gsc-tabData.gsc-tabdActive > div > div.gsc-expansionArea > div:nth-child(1) > div.gs-webResult.gs-result > div.gsc-url-top > div.gs-bidi-start-align.gs-visibleUrl.gs-visibleUrl-long

link_list = []
for article in articles:
    link = article.find_element_by_css_selector("div.gsc-url-top > div.gs-bidi-start-align.gs-visibleUrl.gs-visibleUrl-long").text #get_attribute("href")
    link_list.append(link)
link= pd.DataFrame(link_list, columns=['link'])
link.head() #상위 5개 보여줌
# Out:
#                             link
# 0  www.itworld.co.kr/news/108256
# 1  www.itworld.co.kr/news/137410
# 2  www.itworld.co.kr/news/105638
# 3  www.itworld.co.kr/news/123449
# 4  www.itworld.co.kr/news/140656

# %%
articles = driver.find_elements_by_css_selector("#___gcse_0 > div > div > div > div.gsc-wrapper > div.gsc-resultsbox-visible > div.gsc-resultsRoot.gsc-tabData.gsc-tabdActive > div > div.gsc-expansionArea > div > div.gs-webResult.gs-result")

# %%
 div.gs-webResult.gs-result > div.gsc-table-result > div.gsc-table-cell-snippet-close > div.gs-bidi-start-align.gs-snippet

# %%
#___gcse_0 > div > div > div > div.gsc-wrapper > div.gsc-resultsbox-visible > div.gsc-resultsRoot.gsc-tabData.gsc-tabdActive > div > div.gsc-expansionArea > div:nth-child(1) > div.gs-webResult.gs-result > div.gsc-table-result > div.gsc-table-cell-snippet-close > div.gs-bidi-start-align.gs-snippet

# %%
#preview 뽑아내기
preview_list = []
for article in articles:
    preview = article.find_element_by_css_selector(" div.gsc-table-result > div.gsc-table-cell-snippet-close > div.gs-bidi-start-align.gs-snippet").text
    
    
    
    preview_list.append(preview)
preview=pd.DataFrame(preview_list,columns=['preview'])
preview
# Out:
#                                              preview
# 0  2018년 2월 20일 ... 가트너는 전세계 기업들이 인공지능(AI)을 본격적으로...
# 1  2019년 11월 25일 ... 머신러닝 기반 시스템을 다루고 있다면, 학습 데이터...
# 2  2017년 7월 19일 ... 새로운 맥락(contextual) 분석 기술인 마그넷...
# 3  2019년 5월 29일 ... CPU와 그래픽, AI 작업에 걸쳐 성능이 향상됐고,...
# 4  3일 전 ... AI를 둘러싼 가장 큰 걱정은 머신러닝 기반 모델이 흔히 “블랙박스...
# 5  2019년 7월 2일 ... 고객 여정이 다변화되고 경쟁이 치열해지면서, 서비스로 ...
# 6  2019년 5월 2일 ... 점점 더 많은 기업이 인공지능(AI)과 머신러닝을 활용...
# 7  2019년 11월 13일 ... 주니퍼 네트웍스 자회사인 미스트 시스템즈(www.m...
# 8  2019년 12월 24일 ... 이처럼 도처에 AI의 활용이 늘어나고 있지만 AI에...
# 9  2019년 2월 8일 ... 그것은 바로 AI라는 퍼즐의 중요한 조각인 특정한 기술...

# %%
result=pd.concat([img, title, link], axis=1)
result.tail() #하위5개 보여줌
# Out:
#                                                  img  \
# 5  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 6  https://encrypted-tbn2.gstatic.com/images?q=tb...
# 7  https://encrypted-tbn2.gstatic.com/images?q=tb...
# 8  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 9  https://encrypted-tbn2.gstatic.com/images?q=tb...
#
#                                                title  \
# 5        AMD, 머신러닝용 라데온 인스팅트 GPU 발표…AI 시장 추격 나선다 ...
# 6  “2022년까지 AI 프로젝트 85%가 잘못된 결과 도출"…가트너 - ITWorld...
# 7         향후 10년 AI 투명성의 위험을 완화하는 방법 - ITWorld Korea
# 8  IDG 블로그 | SaaS 기반 AI 학습 서비스의 엄청난 가능성 - ITWorld...
# 9     마그넷 포렌식, AI 기능 더한 디지털 포렌식 솔루션 '마그넷 엑시엄 1.1 ...
#
#                             link
# 5  www.itworld.co.kr/news/102559
# 6  www.itworld.co.kr/news/108256
# 7  www.itworld.co.kr/news/140656
# 8  www.itworld.co.kr/news/137410
# 9  www.itworld.co.kr/news/105638

# %%
# 함수로 만들기
def get_articles(page):
    from selenium import webdriver
    import time
    import pandas as pd
    
    driver =  webdriver.Chrome()
    url = 'http://www.itworld.co.kr/search/?q=AI'#.format(page)
    driver.get(url)
       
    #div = driver.find_elements_by_css_selector('.gsc-wrapper')[0]
    #btn = div.find_elements_by_css_selector('.gsc-cursor-page')[page]

    #___gcse_0 > div > div > div > div.gsc-wrapper > div.gsc-resultsbox-visible > div.gsc-resultsRoot.gsc-tabData.gsc-tabdActive > div > div.gsc-cursor-box.gs-bidi-start-align > div > div.gsc-cursor-page.gsc-cursor-current-page
    
    #btn.click()    
    
    driver.find_element_by_xpath("""//*[@id="___gcse_0"]/div/div/div/div[5]/div[2]/div[1]/div/div[2]/div/div[%s]""" %page).click()
    time.sleep(1)
    
    
    
    #여러데이터 모으기
    articles = driver.find_elements_by_css_selector("#___gcse_0 > div > div > div > div.gsc-wrapper > div.gsc-resultsbox-visible > div.gsc-resultsRoot.gsc-tabData.gsc-tabdActive > div > div.gsc-expansionArea > div > div.gs-webResult.gs-result")
    
    
    #제목
    title_list = []
    for article in articles:
        title = article.find_element_by_css_selector("div.gsc-thumbnail-inside > div > a").text 
        title_list.append(title)
    title =pd.DataFrame(title_list, columns=['title'])
    
   
    #링크만 뽑아내기
    link_list = []
    for article in articles:
        link = article.find_element_by_css_selector("div.gsc-url-top > div.gs-bidi-start-align.gs-visibleUrl.gs-visibleUrl-long").text
        link_list.append(link)
    link= pd.DataFrame(link_list, columns=['link'])
    
    #이미지만 뽑아내기
    img_list = []
    for article in articles:
        img = article.find_element_by_css_selector("div.gsc-table-cell-thumbnail.gsc-thumbnail > div > a > img").get_attribute("src") 
        
        
        img_list.append(img)
    img=pd.DataFrame(img_list,columns=['img'])
    
    result=pd.concat([img, title, link], axis=1) #axis=1 은 열 !!! 
   
    driver.quit()
    return result

# %%
get_articles(1)
# Out:
#                                                  img  \
# 0  https://encrypted-tbn3.gstatic.com/images?q=tb...
# 1  https://encrypted-tbn1.gstatic.com/images?q=tb...
# 2  https://encrypted-tbn3.gstatic.com/images?q=tb...
# 3  https://encrypted-tbn3.gstatic.com/images?q=tb...
# 4  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 5  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 6  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 7  https://encrypted-tbn3.gstatic.com/images?q=tb...
# 8  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 9  https://encrypted-tbn1.gstatic.com/images?q=tb...
#
#                                                title  \
# 0    AI 기반의 위협 탐지가 아직 시장을 장악하지 못한 이유 - ITWorld Korea
# 1           네트워크 운영 : AI와 ML의 새로운 역할 - ITWorld Korea
# 2  IT 미래를 이끄는 삼두마차, "AI, IoT, 하이브리드 클라우드" - ITWor...
# 3  AI 여정을 가속화하는 핵심 로드맵 - IDG Summary - ITWorld Korea
# 4         기업이 반드시 도입해야 하는 AI 활용법 5가지 - ITWorld Korea
# 5          "사이버보안의 가장 큰 위협이 될 수 있는" AI 퍼징이란 무엇인가 ...
# ...

# %%
# 자동으로 일정 페이지 크롤링해줘서 데이터프레임 만들어주기
def Tech_crunch(startpage, endpage):
    import pandas as pd
    df=pd.DataFrame([])
    for i in range(startpage, endpage+1):
        temp=get_articles(i)
        df= pd.concat([df,temp],axis=0)
    #index 번호 다시 매기기
    df.reset_index(drop=True, inplace=True)
    return df

# %%
final_df= Tech_crunch(1,10)

# %%
final_df.tail(3)
#final_df
# Out:
#                                                   img  \
# 97  https://encrypted-tbn2.gstatic.com/images?q=tb...
# 98  https://encrypted-tbn2.gstatic.com/images?q=tb...
# 99  https://encrypted-tbn2.gstatic.com/images?q=tb...
#
#                                                 title  \
# 97  시스코, “AI·머신러닝으로 단순·안전·스마트한 네트워크 구현” - ITWorld ...
# 98    체험 리뷰 | AI와 만난 화웨이 메이트 10, “신경망 프로세서가 만드는 5 ...
# 99       셀바스 AI-텔레투게더, 음성인식 기반의 AI 회의록 서비스 관련 MOU ...
#
#                              link
# 97  www.itworld.co.kr/news/124137
# 98  www.itworld.co.kr/news/106763
# 99  www.itworld.co.kr/news/125483

# %%
final_df.to_csv("Tech_crunch.csv", index=False, encoding='utf-8' )
